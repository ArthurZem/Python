# %% [markdown]
# # Regressão linear Multipla

# %%
# !pip install plotly --upgrade

# %%
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_cerveja = pd.read_csv('/content/drive/MyDrive/Consumo_cerveja - Consumo_cerveja.csv')
base_cerveja
#leitura e amostragem da tabela

# %%
base_cerveja = base_cerveja.dropna()
base_cerveja

# %%
base_cerveja.describe()
#descrição da tabela com valores mtotais, média, mínima, desvio padrão etc

# %%
base_cerveja.info()
#info de tipos de variáveis, quantidade de itens etc

# %%
base_cerveja.isnull().sum()
#número de valores null em cada coluna

# %%
df = pd.DataFrame(base_cerveja)
df['Temperatura Media (C)'] = df['Temperatura Media (C)'].str.replace(',' , '.')
df['Temperatura Minima (C)'] = df['Temperatura Minima (C)'].str.replace(',' , '.')
df['Temperatura Maxima (C)'] = df['Temperatura Maxima (C)'].str.replace(',' , '.')
df['Precipitacao (mm)'] = df['Precipitacao (mm)'].str.replace(',' , '.')

#conversão de "," para "." nos valores

# %%
df['Temperatura Media (C)'] = df['Temperatura Media (C)'].astype(float)
df['Temperatura Minima (C)'] = df['Temperatura Minima (C)'].astype(float)
df['Temperatura Maxima (C)'] = df['Temperatura Maxima (C)'].astype(float)
df['Precipitacao (mm)'] = df['Precipitacao (mm)'].astype(float)

df
#conversão para float

# %%
base_cerveja.corr()

# %%
x_cerveja = df.iloc[:, 2:3].values
x_cerveja

# %%
y_cerveja = df.iloc[:, 4:5].values
y_cerveja

# %%
from sklearn.model_selection import train_test_split
x_cerveja_treinamento, x_cerveja_teste, y_Cerveja_treinamento, y_Treinamento_teste = train_test_split(x_cerveja, y_cerveja, test_size = 0.3, random_state = 0)

# %%
x_cerveja_treinamento.shape, x_cerveja_teste.shape
# Out:
# ((255, 1), (110, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor_multiplo_cerveja = LinearRegression()
regressor_multiplo_cerveja.fit(x_cerveja_treinamento, y_Cerveja_treinamento)
# Out:
# LinearRegression()

# %%
regressor_multiplo_cerveja.intercept_
# Out:
# array([-0.45902692])

# %%
regressor_multiplo_cerveja.coef_
# Out:
# array([[0.30454731]])

# %%
coeff_df = pd.DataFrame(regressor_multiplo_cerveja.coef_,x_cerveja.columns,columns=['Coefficient'])
coeff_df

# %% [markdown]
# ## Predições do nosso modelo
#
# Vamos pegar as previsões em nosso conjunto de testes e ver o quão bem!

# %%
regressor_multiplo_cerveja.score(x_cerveja_treinamento, y_cerveja_treinamento)

# %%
regressor_multiplo_cerveja.score(x_cerveja_teste, y_cerveja_teste)
# Out:
# 0.00900701535891979

# %%
predictions = regressor_multiplo_cerveja.predict(x_cerveja_teste)
predictions

# %% [markdown]
# ## Métricas de avaliação de regressão
#
#
# Aqui estão três métricas de avaliação comuns para problemas de regressão:
#
# **Mean absolute error ** (erro absoluto médio) (MAE) é a média do valor absoluto dos erros:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# ** Mean Squared Error ** (erro médio quadrático) (MSE) é a média dos erros quadrados:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# ** Root Mean Square Error ** (raiz do erro quadrático médio) (RMSE) é a raiz quadrada da média dos erros quadrados:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparando estas métricas:
#
# - **MAE** é o mais fácil de entender, porque é o erro médio.
# - **MSE** é mais popular que o MAE, porque a MSE "puniria" erros maiores, o que tende a ser útil no mundo real.
# - **RMSE** é ainda mais popular do que MSE, porque o RMSE é interpretável nas unidades "y".
#
# Todas estas são ** funções de perda **, porque queremos minimizá-las.

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_cerveja_teste, predictions))
print('MSE:', metrics.mean_squared_error(y_cerveja_teste, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_cerveja_teste, predictions)))
